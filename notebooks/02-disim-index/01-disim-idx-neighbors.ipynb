# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from urban_scenario import resistencia_stquo_scenario
from CENSAr.plots import compare_chropleths

# %%
# raster data analysis outputs
path00 = '../../CENSAr/data/ManchaUrbana_Resistencia_1999.geojson'
path10 = '../../CENSAr/data/ManchaUrbana_Resistencia_2010.geojson'
path20 = '../../CENSAr/data/ManchaUrbana_Resistencia_2022.geojson'
urban_growth = resistencia_stquo_scenario(path00, path10, path20)
# Out:
# [16:25:48] INFO     loading                                                                      ]8;id=148071;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py\datasources.py]8;;\:]8;id=138637;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py#112\112]8;;\
#                     `https://storage.googleapis.com/python_mdg/censar_data/tipo_vivienda_radios_
#                     chaco_2001.csv`
# [16:25:49] INFO     loading                                                                      ]8;id=588501;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py\datasources.py]8;;\:]8;id=748453;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py#112\112]8;;\
#                     `https://storage.googleapis.com/python_mdg/censar_data/tipo_vivienda_radios_
#                     chaco_2010.csv`
#            INFO     loading                                                                      ]8;id=840660;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py\datasources.py]8;;\:]8;id=779201;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py#112\112]8;;\
#                     `https://storage.googleapis.com/python_mdg/censar_data/tipo_vivienda_radios_
#                     chaco_2010.csv`
#            INFO     loading                                                                      ]8;id=595064;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py\datasources.py]8;;\:]8;id=652944;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py#134\134]8;;\
#                     `https://storage.googleapis.com/python_mdg/censar_data/personas_radios_chaco
#                     _2001.csv`
#            INFO     loading                                                                      ]8;id=270691;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py\datasources.py]8;;\:]8;id=333606;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py#134\134]8;;\
#                     `https://storage.googleapis.com/python_mdg/censar_data/personas_radios_chaco
#                     _2010.csv`
# [16:25:50] INFO     loading,                                                                     ]8;id=138246;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py\datasources.py]8;;\:]8;id=17773;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/datasources.py#168\168]8;;\
#                     `https://storage.googleapis.com/python_mdg/censar_data/persproyect_depto_cha
#                     co.csv`
# The total number of projected households/residential units is 132527
#            INFO     Applying named aggregation `tipo vivienda particular`                                ]8;id=480374;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=661307;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#67\67]8;;\
#            WARNING  Extra columns found for mapping situacion de calle: {'persona viviendo en la        ]8;id=331815;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=765266;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#123\123]8;;\
#                     calle'}. Extra columns will be ignored.
#            INFO     Applying named aggregation `tipo vivienda particular`                                ]8;id=494161;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=13555;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#67\67]8;;\
#            WARNING  Extra columns found for mapping formal: {'casa a', 'casa b'}. Extra columns will be ]8;id=808333;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=163483;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#123\123]8;;\
#                     ignored.
#            WARNING  Extra columns found for mapping situacion de calle: {'persona viviendo en la        ]8;id=204251;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=444106;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#123\123]8;;\
#                     calle'}. Extra columns will be ignored.
#            INFO     Applying named aggregation `tipo vivienda particular`                                ]8;id=442035;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=387345;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#67\67]8;;\
#            WARNING  Extra columns found for mapping formal: {'casa a', 'casa b'}. Extra columns will be ]8;id=969592;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=4517;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#123\123]8;;\
#                     ignored.
#            WARNING  Extra columns found for mapping situacion de calle: {'persona viviendo en la        ]8;id=711544;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py\core.py]8;;\:]8;id=489367;file:///home/fede/CEEU/CENSAr/CENSAr/CENSAr/aggregation/core.py#123\123]8;;\
#                     calle'}. Extra columns will be ignored.

# %%
tipo_vivienda_agg_2020 =  urban_growth[2020]
envolvente_resistencia_20 =  urban_growth['env20']

# %%
# BARRIOS/ZONAS
zona_sup = gpd.read_file("../../CENSAr/data/zonas_resistencia.geojson")
#zona_sup = gpd.read_file("../../CENSAr/data/barrios.shp")
zona_sup.rename(columns={'id':'barrio'}, inplace=True)

# %%
zona_inf = tipo_vivienda_agg_2020.copy()
zona_inf.reset_index(inplace=True)
zona_inf['area_tot'] = zona_inf.area
zonas_inter = gpd.overlay(zona_sup, zona_inf, how='intersection')

zonas_inter['area_par'] = zonas_inter.area
zonas_inter['area_porc'] = round(zonas_inter['area_par'] / zonas_inter['area_tot'], 3)
zonas_inter = zonas_inter.sort_values(by='area_porc', ascending=False).reset_index(drop=True)
zonas_inter.drop_duplicates(subset='link', keep='first', inplace=True)

zonas_inter.drop(columns=['area_par', 'area_tot', 'area_porc'], inplace=True)
zonas_inter = zona_inf.merge(zonas_inter[['link', 'barrio', 'grupo']], on='link')
zonas_inter.head(2)
# Out:
# /tmp/ipykernel_5831/1850652164.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf['area_tot'] = zona_inf.area
# /tmp/ipykernel_5831/1850652164.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter['area_par'] = zonas_inter.area
#         link                                           geometry  total
# 0  221402105  POLYGON ((-58.94803 -27.51940, -58.94750 -27.5...    419  \
# 1  221402106  MULTIPOLYGON (((-58.94180 -27.51231, -58.94176...    554
#
#    situacion de calle  informal  formal  area_tot  barrio grupo
# 0                   0      81.0   338.0  0.000027       1     c
# 1                   0      81.0   473.0  0.000073       1     c

# %%
f, ax = plt.subplots()

zonas_inter.plot(ax=ax, color='red')
zona_sup.plot(ax=ax, color='grey');

# %%
# TODO: Generalizar y optimizar el calculo de la disimilitud por relaciones de vecindad (ver Issue#xxx)
zona_inf['area_tot'] = zona_inf.area
zona_inf['indice'] = -1
zona_inf['indice_count'] = 0
zona_inf['area_tot'] = zona_inf.area

results = {}

for b in [[0.003, "3"], [0.005, '5'], [0.007, "7"],  [0.009, '9']]:
    for r in range(len(zona_inf)):
        zona_inf_test = zona_inf.loc[[r]]
        zona_inf_buffer = zona_inf_test[['geometry']].copy()
        zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])

        zonas_inter_buffer = gpd.overlay(zona_inf_buffer, zona_inf, how='intersection')
        zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
        zonas_inter_buffer['area_porc'] = round(zonas_inter_buffer['area_par'] / zonas_inter_buffer['area_tot'], 3)
        zonas_inter_buffer = zonas_inter_buffer.loc[zonas_inter_buffer.area_porc > 0.30]

        if len(zonas_inter_buffer) > 1:
            zonas_inter_buffer['formal_tot'] = zonas_inter_buffer['formal'].sum()
            zonas_inter_buffer['informal_tot'] = zonas_inter_buffer['informal'].sum()

            lista_valores = abs((zonas_inter_buffer['formal'] / zonas_inter_buffer['formal_tot']) - (zonas_inter_buffer['informal'] / zonas_inter_buffer['informal_tot']))
            disimilitud_indice = round((lista_valores.sum()) * 0.5, 3)

            zona_inf.loc[r, 'indice'] = disimilitud_indice
            zona_inf.loc[r, 'indice_count'] = len(zonas_inter_buffer)

        zonas_inter_buffer_2 = zonas_inter_buffer.loc[zonas_inter_buffer.link != list(zona_inf.loc[r, ['link']])[0]]
        zonas_inter_buffer_2['formal_tot'] = zonas_inter_buffer_2['formal'].sum()
        zonas_inter_buffer_2['informal_tot'] = zonas_inter_buffer_2['informal'].sum()
        lista_valores_2 = abs((zonas_inter_buffer_2['formal'] / zonas_inter_buffer_2['formal_tot']) - 
                              (zonas_inter_buffer_2['informal'] / zonas_inter_buffer_2['informal_tot']))
        disimilitud_indice_2 = round((lista_valores_2.sum()) * 0.5, 3)

        zona_inf.loc[r, 'indice_vecindad'] = disimilitud_indice_2

        # detección de radios que al agregarlos empeoran la similitud del entorno
        zona_inf['dif_indices_entornos'] = zona_inf['indice_vecindad'] - zona_inf['indice'] 
        zona_inf['dif_indices_entornos_abs'] = abs(zona_inf['indice_vecindad'] - zona_inf['indice'] )

    results[b[1]] = zona_inf.loc[zona_inf.indice != -1]
# Out:
# /tmp/ipykernel_5831/3623053312.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf['area_tot'] = zona_inf.area
# /tmp/ipykernel_5831/3623053312.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf['area_tot'] = zona_inf.area
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# ...
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /tmp/ipykernel_5831/3623053312.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zona_inf_buffer.geometry = zona_inf_test.buffer(b[0])
# /tmp/ipykernel_5831/3623053312.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zonas_inter_buffer['area_par'] = zonas_inter_buffer.area
# /home/fede/CEEU/CENSAr/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
results.keys()
# Out:
# dict_keys(['3', '5', '7', '9'])

# %%
results['3'].head()
# Out:
#         link                                           geometry  total
# 0  221402203  MULTIPOLYGON (((-58.92564 -27.54318, -58.92521...    103  \
# 1  221402105  POLYGON ((-58.94803 -27.51940, -58.94750 -27.5...    419
# 2  221402106  MULTIPOLYGON (((-58.94180 -27.51231, -58.94176...    554
# 3  221402102  POLYGON ((-58.94171 -27.51378, -58.94176 -27.5...    298
# 4  221402807  MULTIPOLYGON (((-58.95301 -27.50669, -58.95286...    175
#
#    situacion de calle  informal  formal  area_tot  indice  indice_count
# 0                   0      33.0    70.0  0.000008   0.008             2  \
# 1                   0      81.0   338.0  0.000027   0.278             3
# 2                   0      81.0   473.0  0.000073   0.399             4
# 3                   0       6.0   292.0  0.000010   0.418             4
# 4                   0      36.0   139.0  0.000030   0.400             3
#
#    indice_vecindad  dif_indices_entornos  dif_indices_entornos_abs
# 0            0.000                -0.008                     0.008
# 1            0.398                 0.120                     0.120
# 2            0.569                 0.170                     0.170
# 3            0.316                -0.102                     0.102
# 4            0.182                -0.218                     0.218

# %%
compare_chropleths(
    results['3'],
    results['3'],
    results['3'],
    column=["indice","indice_vecindad","dif_indices_entornos_abs"],
    titles=['Indice de disimilitud', 'Indice de vecindad', 'Indice de discontinuidad (radios que empeoran el entorno)'],
    urban_boundaries = [envolvente_resistencia_20, envolvente_resistencia_20, envolvente_resistencia_20],
    figsize=(20,12),
    cmap = 'YlOrRd'
)
# Out:
# {'cmap': 'YlOrRd', 'legend': True, 'legend_kwds': {'shrink': 0.3}}

# %%
compare_chropleths(
    results['9'],
    results['9'],
    results['9'],
    column=["indice","indice_vecindad","dif_indices_entornos_abs"],
    titles=['Indice de disimilitud', 'Indice de vecindad', 'Indice de discontinuidad (radios que empeoran el entorno)'],
    urban_boundaries = [envolvente_resistencia_20, envolvente_resistencia_20, envolvente_resistencia_20],
    figsize=(20,12),
    cmap = 'YlOrRd'
)
# Out:
# {'cmap': 'YlOrRd', 'legend': True, 'legend_kwds': {'shrink': 0.3}}
